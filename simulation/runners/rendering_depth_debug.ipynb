# %% [markdown]
# # Rendering Prep
#
# This notebook is for prototyping/prepping the driver for rendering the freespace dynamics dataset
#
# NOTE: This was converted to a script and is run via command line.

# %%
import os
import sys
from pathlib import Path
import pickle

import bpy
import mathutils
import numpy as np

# Imports from this repository
sys.path.append("../../")
sys.path.append("../")
from simulation.cloth_3d_util.accessor import Cloth3DCanonicalAccessor
from simulation.cloth_3d_util.util import loadInfo
from simulation.pipeline.simulate_garment_hanging_rest_state import \
    simulate_garment_hanging_rest_state
from simulation.blender_util_dylan.physics import set_sim_output_as_default_mesh_shape
from simulation.blender_util_dylan.checkpointer import BlendFileCheckpointer
from simulation.blender_util_dylan.gripper import GripperAnimation
from simulation.blender_util_dylan.debug import print_obj_keyframe_coordinates

from simulation.blender_util_dylan.render import enable_gpu_renders, render_dylan
from simulation.blender_util_dylan.debug import print_nested_dict_types
from simulation.blender_util.camera import generate_intrinsic
from simulation.cloth_3d_util.accessors.access_functions import (
    get_info, get_garment_texture, get_garment_metadata 
)

# %load_ext autoreload
# %autoreload 2
# Out:
# WARN (bgl): source/blender/python/generic/bgl.c:2654 BPyInit_bgl: 'bgl' imported without an OpenGL backend. Please update your add-ons to use the 'gpu' module. In Blender 4.0 'bgl' will be removed.
# /home/dcolli23/.local/share/virtualenvs/simulation-7NaVsHdv/lib/python3.10/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/dcolli23/.local/share/virtualenvs/simulation-7NaVsHdv/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/dcolli23/.local/share/virtualenvs/simulation-7NaVsHdv/lib/python3.10/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/dcolli23/.local/share/virtualenvs/simulation-7NaVsHdv/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
FILE_ROOT = Path(os.getcwd())
CLOTH3D_PATH = Path(os.path.expanduser("~/DataLocker/datasets/CLOTH3D/training/"))
OUTPUT_ROOT = FILE_ROOT / ".." / "script_output" / "render_debug"
OUTPUT_ROOT.mkdir(exist_ok=True)
GARMENTNETS_SAMPLE_DATASET_ZARR = (FILE_ROOT / ".." / ".." / "data" / 
                                   "garmentnets_simulation_dataset_sample.zarr")
assert (GARMENTNETS_SAMPLE_DATASET_ZARR.exists())
GARMENTNETS_SAMPLE_PATH = ["Tshirt", "samples"]

NUM_ACTION_SEQUENCES = 5
DYNAMICS_ANIMATION_DIR_TEMPLATE = "dynamics_seq_{idx}"
DYNAMICS_ANIMATION_FILENAME = "dynamics_animation.blend"

PLANE_OFFSET = 0.025  # [m]

# %% [markdown]
# ## First, Render The Hanging Resting State (GarmentNets Input)

# %%
num_camera_angles = 4
camera_intrinsic = generate_intrinsic(1024, 1024, 2048)

for sample_dir in OUTPUT_ROOT.iterdir():
    sample_key = sample_dir.name

    render_output_example_1 = sample_dir / "rgb_0.png"
    render_output_example_2 = sample_dir / "uviz_3.exr"
    if render_output_example_1.exists() and render_output_example_2.exists():
        print(f"Already rendered hanging state for '{sample_key}', skipping render.")
        continue

    print(f"Animating {sample_key} resting state (GarmentNets input)")

    sample_id, garment_name, grip_vertex_idx_key = sample_key.split('_')
    
    # Load the initial sim results
    results_dict_filepath = sample_dir / "hanging_rest_state_results.pkl"
    assert(results_dict_filepath.exists())
    results_dict_smpl = pickle.load(results_dict_filepath.open('rb'))
    # print(results)
    cloth_state = results_dict_smpl["cloth_state"]

    assert (int(grip_vertex_idx_key) == results_dict_smpl["grip_vertex_idx"])

    # Load the garment information dictionary.
    accessor = Cloth3DCanonicalAccessor(CLOTH3D_PATH)
    sample_data = accessor.get_sample_data(sample_id, garment_name)
    print_nested_dict_types(sample_data)


    # Load the hanging rest state blend file.
    blend_path = sample_dir / "hanging_rest_state.blend"
    assert(blend_path.exists())
    bpy.ops.wm.open_mainfile(filepath=blend_path.as_posix())

    # Add the world material I accidentally deleted when simulating hanging rest state
    # bpy.ops.world.new()
    # print(bpy.data.worlds.keys())


    info = get_info(CLOTH3D_PATH, sample_id)
    garment_texture = get_garment_texture(CLOTH3D_PATH, sample_id, garment_name, info=info)
    garment_meta = get_garment_metadata(CLOTH3D_PATH, sample_id, garment_name, info=info)
    gender = garment_meta['gender']
    fabric = garment_meta['garment_fabric']

    enable_gpu_renders()
    render_dylan(
        output_path=sample_dir, 
        sample_id=sample_id, 
        garment_name=garment_name, 
        gender=gender, 
        fabric=fabric, 
        garment_verts=cloth_state["verts"], 
        garment_faces=cloth_state["faces"],
        garment_uv_verts=cloth_state["uv_verts"], 
        garment_uv_faces=cloth_state["uv_faces"], 
        garment_texture=garment_texture, 
        num_camera_angles=num_camera_angles, 
        camera_intrinsic=camera_intrinsic,
        z_offset=-0.4
    )

    hanging_blend_output_path = sample_dir / "render_hanging_debug.blend"
    bpy.ops.wm.save_as_mainfile(filepath=hanging_blend_output_path.as_posix())
    break
# Out:
# Animating 00380_Tshirt_509 resting state (GarmentNets input)
# human_verts <class 'numpy.ndarray'>
# human_faces <class 'numpy.ndarray'>
# human_gender <class 'int'>
# garment_verts <class 'numpy.ndarray'>
# garment_faces <class 'list'>
# garment_uv_verts <class 'numpy.ndarray'>
# garment_uv_faces <class 'list'>
# garment_fabric <class 'str'>
# garment_texture <class 'numpy.ndarray'>
# Read blend: /home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/runners/../script_output/render_debug/00380_Tshirt_509/hanging_rest_state.blend
# CUDA_NVIDIA GeForce RTX 2080 Ti_0000:01:00 True CUDA
# CPU False CPU
# CUDA_NVIDIA GeForce RTX 2080 Ti_0000:01:00_OptiX False OPTIX
# Dylan added to get z values as alpha channel!
# Setting render configuration and printing failed sets.
# 	denoiser
# 	sampling_pattern
# Dylan need to change use zbuffer to True??
# Fra:0 Mem:154.28M (Peak 154.28M) | Time:00:00.18 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | cloth
# Fra:0 Mem:202.75M (Peak 216.42M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Procedurals
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Background
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes Flags
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:0 Mem:126.85M (Peak 216.42M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes
# Fra:0 Mem:135.97M (Peak 216.42M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:0 Mem:149.64M (Peak 216.42M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:0 Mem:149.64M (Peak 216.42M) | Time:00:00.34 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:0 Mem:149.64M (Peak 216.42M) | Time:00:00.34 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:0 Mem:183.83M (Peak 216.42M) | Time:00:00.46 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:0 Mem:186.11M (Peak 216.42M) | Time:00:00.46 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:0 Mem:185.60M (Peak 216.42M) | Time:00:00.50 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:0 Mem:185.60M (Peak 216.42M) | Time:00:00.50 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.51 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Objects Flags
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Images
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Camera Volume
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:0 Mem:234.62M (Peak 234.62M) | Time:00:00.54 | Mem:80.68M, Peak:80.68M | Scene, ViewLayer | Updating Integrator
# Fra:0 Mem:235.62M (Peak 235.62M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Film
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Baking
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:0 Mem:239.88M (Peak 239.88M) | Time:00:00.55 | Mem:434.43M, Peak:434.43M | Scene, ViewLayer | Sample 0/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.63 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Sample 1/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.63 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Finished
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.69 | Compositing
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.69 | Compositing | Determining resolution
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.69 | Compositing | Initializing execution
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 1-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 2-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 3-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 5-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 6-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 7-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 8-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 9-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 10-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 4-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 11-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 12-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 13-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 14-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 15-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.70 | Compositing | Tile 16-16
# Fra:0 Mem:162.35M (Peak 399.88M) | Time:00:00.70 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/uviz_0.exr'
#  Time: 00:00.72 (Saving: 00:00.02)
#
# Dylan need to change use zbuffer to True??
# Fra:0 Mem:154.28M (Peak 154.28M) | Time:00:00.20 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | cloth
# Fra:0 Mem:202.75M (Peak 216.43M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Procedurals
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Background
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes Flags
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes
# Fra:0 Mem:135.97M (Peak 216.43M) | Time:00:00.36 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.36 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.36 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.36 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:0 Mem:183.83M (Peak 216.43M) | Time:00:00.48 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:0 Mem:186.11M (Peak 216.43M) | Time:00:00.48 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:0 Mem:185.60M (Peak 216.43M) | Time:00:00.54 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:0 Mem:185.60M (Peak 216.43M) | Time:00:00.54 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Objects Flags
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.57 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.57 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Images
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.57 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Camera Volume
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.57 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.57 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.57 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:0 Mem:234.62M (Peak 234.62M) | Time:00:00.58 | Mem:80.68M, Peak:80.68M | Scene, ViewLayer | Updating Integrator
# Fra:0 Mem:235.62M (Peak 235.62M) | Time:00:00.58 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Film
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.59 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.59 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Baking
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.59 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:0 Mem:239.88M (Peak 239.88M) | Time:00:00.59 | Mem:434.43M, Peak:434.43M | Scene, ViewLayer | Sample 0/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.67 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Sample 1/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.67 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Finished
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.73 | Compositing
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.73 | Compositing | Determining resolution
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.73 | Compositing | Initializing execution
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 1-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 2-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 3-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 5-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 9-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 7-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 8-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 6-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 4-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 10-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 11-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 12-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 13-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 14-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 15-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 16-16
# Fra:0 Mem:162.35M (Peak 399.88M) | Time:00:00.74 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/uviz_1.exr'
#  Time: 00:00.76 (Saving: 00:00.01)
#
# Dylan need to change use zbuffer to True??
# Fra:0 Mem:154.28M (Peak 154.28M) | Time:00:00.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | cloth
# Fra:0 Mem:202.75M (Peak 216.43M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Procedurals
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Background
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes Flags
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes
# Fra:0 Mem:135.97M (Peak 216.43M) | Time:00:00.36 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.36 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.36 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.36 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:0 Mem:183.83M (Peak 216.43M) | Time:00:00.49 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:0 Mem:186.11M (Peak 216.43M) | Time:00:00.49 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:0 Mem:185.60M (Peak 216.43M) | Time:00:00.53 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:0 Mem:185.60M (Peak 216.43M) | Time:00:00.54 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.55 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Objects Flags
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Images
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Camera Volume
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.56 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:0 Mem:234.62M (Peak 234.62M) | Time:00:00.58 | Mem:80.68M, Peak:80.68M | Scene, ViewLayer | Updating Integrator
# Fra:0 Mem:235.62M (Peak 235.62M) | Time:00:00.58 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Film
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.58 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.58 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Baking
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.58 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:0 Mem:239.88M (Peak 239.88M) | Time:00:00.58 | Mem:434.43M, Peak:434.43M | Scene, ViewLayer | Sample 0/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.66 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Sample 1/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.66 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Finished
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.72 | Compositing
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.72 | Compositing | Determining resolution
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.72 | Compositing | Initializing execution
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 1-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 2-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 3-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 4-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 8-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 6-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 7-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 5-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 9-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 10-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 11-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 12-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 13-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 14-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 15-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 16-16
# Fra:0 Mem:162.35M (Peak 399.88M) | Time:00:00.73 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/uviz_2.exr'
#  Time: 00:00.75 (Saving: 00:00.01)
#
# Dylan need to change use zbuffer to True??
# Fra:0 Mem:154.28M (Peak 154.28M) | Time:00:00.18 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | cloth
# Fra:0 Mem:202.75M (Peak 216.43M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Scene
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Shaders
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Procedurals
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Background
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Camera
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes Flags
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:0 Mem:126.85M (Peak 216.43M) | Time:00:00.33 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Meshes
# Fra:0 Mem:135.97M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.34 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.34 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:0 Mem:149.64M (Peak 216.43M) | Time:00:00.34 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:0 Mem:183.83M (Peak 216.43M) | Time:00:00.46 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:0 Mem:186.11M (Peak 216.43M) | Time:00:00.46 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:0 Mem:185.60M (Peak 216.43M) | Time:00:00.50 | Mem:13.68M, Peak:13.68M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:0 Mem:185.60M (Peak 216.43M) | Time:00:00.50 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.51 | Mem:31.66M, Peak:31.66M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Objects Flags
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Images
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Camera Volume
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights
# Fra:0 Mem:225.50M (Peak 225.50M) | Time:00:00.52 | Mem:71.56M, Peak:71.56M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:0 Mem:234.62M (Peak 234.62M) | Time:00:00.54 | Mem:80.68M, Peak:80.68M | Scene, ViewLayer | Updating Integrator
# Fra:0 Mem:235.62M (Peak 235.62M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Film
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Lookup Tables
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Baking
# Fra:0 Mem:235.63M (Peak 235.63M) | Time:00:00.54 | Mem:81.68M, Peak:81.68M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:0 Mem:239.88M (Peak 239.88M) | Time:00:00.54 | Mem:434.43M, Peak:434.43M | Scene, ViewLayer | Sample 0/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.62 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Sample 1/1
# Fra:0 Mem:335.88M (Peak 399.88M) | Time:00:00.62 | Mem:482.43M, Peak:482.43M | Scene, ViewLayer | Finished
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.73 | Compositing
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.73 | Compositing | Determining resolution
# Fra:0 Mem:142.35M (Peak 399.88M) | Time:00:00.73 | Compositing | Initializing execution
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 1-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.73 | Compositing | Tile 2-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 3-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 4-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 5-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 6-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 7-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 9-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 8-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 10-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 11-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 12-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 13-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 14-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 15-16
# Fra:0 Mem:162.41M (Peak 399.88M) | Time:00:00.74 | Compositing | Tile 16-16
# Fra:0 Mem:162.35M (Peak 399.88M) | Time:00:00.74 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/uviz_3.exr'
#  Time: 00:00.76 (Saving: 00:00.01)
#
# Delete me!!!
# Info: Saved "render_debugging_uviz.blend"
# Setting render configuration and printing failed sets.
# Fra:0 Mem:143.13M (Peak 143.13M) | Time:00:00.04 | Syncing cloth
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.16 | Syncing Empty
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.16 | Syncing main_camera
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.20 | Rendering 1 / 65 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.24 | Rendering 26 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.27 | Rendering 51 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.28 | Rendering 64 / 64 samples
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.30 | Compositing
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.30 | Compositing | Determining resolution
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.30 | Compositing | Initializing execution
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 2-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 4-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 3-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 5-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 6-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 10-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 7-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 9-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 1-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 8-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 11-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 13-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 12-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 14-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 15-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.30 | Compositing | Tile 16-16
# Fra:0 Mem:208.17M (Peak 208.98M) | Time:00:00.30 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/rgb_0.png'
#  Time: 00:00.38 (Saving: 00:00.07)
#
# Fra:0 Mem:143.13M (Peak 143.13M) | Time:00:00.05 | Syncing cloth
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.12 | Syncing Empty
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.12 | Syncing main_camera
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.12 | Rendering 1 / 65 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.16 | Rendering 26 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.19 | Rendering 51 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.20 | Rendering 64 / 64 samples
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.22 | Compositing
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.22 | Compositing | Determining resolution
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.22 | Compositing | Initializing execution
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 1-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 2-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 3-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 4-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 5-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 6-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 7-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 9-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 8-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 10-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 11-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 12-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 13-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 14-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 15-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.22 | Compositing | Tile 16-16
# Fra:0 Mem:208.17M (Peak 208.98M) | Time:00:00.22 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/rgb_1.png'
#  Time: 00:00.30 (Saving: 00:00.08)
#
# Fra:0 Mem:143.13M (Peak 143.13M) | Time:00:00.04 | Syncing cloth
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.15 | Syncing Empty
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.15 | Syncing main_camera
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.15 | Rendering 1 / 65 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.19 | Rendering 26 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.21 | Rendering 51 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.23 | Rendering 64 / 64 samples
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.24 | Compositing
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.24 | Compositing | Determining resolution
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.24 | Compositing | Initializing execution
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 1-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 2-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 8-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 9-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 5-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 6-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 7-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 3-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 10-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.24 | Compositing | Tile 4-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.25 | Compositing | Tile 11-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.25 | Compositing | Tile 12-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.25 | Compositing | Tile 13-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.25 | Compositing | Tile 14-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.25 | Compositing | Tile 15-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.25 | Compositing | Tile 16-16
# Fra:0 Mem:208.17M (Peak 208.98M) | Time:00:00.25 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/rgb_2.png'
#  Time: 00:00.33 (Saving: 00:00.07)
#
# Fra:0 Mem:143.13M (Peak 143.13M) | Time:00:00.03 | Syncing cloth
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.10 | Syncing Empty
# Fra:0 Mem:188.97M (Peak 201.65M) | Time:00:00.10 | Syncing main_camera
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.10 | Rendering 1 / 65 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.14 | Rendering 26 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.16 | Rendering 51 / 64 samples
# Fra:0 Mem:188.98M (Peak 201.65M) | Time:00:00.18 | Rendering 64 / 64 samples
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.19 | Compositing
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.19 | Compositing | Determining resolution
# Fra:0 Mem:188.17M (Peak 208.98M) | Time:00:00.19 | Compositing | Initializing execution
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.19 | Compositing | Tile 1-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 5-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 2-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 8-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 9-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 3-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 7-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 6-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 4-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 10-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 11-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 12-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 13-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 14-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 15-16
# Fra:0 Mem:208.24M (Peak 208.98M) | Time:00:00.20 | Compositing | Tile 16-16
# Fra:0 Mem:208.17M (Peak 208.98M) | Time:00:00.20 | Compositing | De-initializing execution
# Saved: '/home/dcolli23/code/school/rob599_deeprob/projects/final/garmentnets_tracking/simulation/script_output/render_debug/00380_Tshirt_509/rgb_3.png'
#  Time: 00:00.28 (Saving: 00:00.08)
#
# Info: Saved "render_hanging_debug.blend"

# %%
# Iterate through the action sequences first so we still get good sample coverage even if we have to
# stop the rendering early to train
for seq_idx in range(NUM_ACTION_SEQUENCES):
    for sample_dir in OUTPUT_ROOT.iterdir():
        sample_key = sample_dir.name
        print(f"Animating {sample_key}, action sequence: {seq_idx}")

        full_animation_blend_path = (sample_dir 
                                     / DYNAMICS_ANIMATION_DIR_TEMPLATE.format(idx=seq_idx) 
                                     / DYNAMICS_ANIMATION_FILENAME)
        
        assert(full_animation_blend_path.exists())

        sample_id, garment_name, grip_vertex_idx_key = sample_key.split('_')
        
        # Load the initial sim results
        results_dict_filepath = sample_dir / "hanging_rest_state_results.pkl"
        assert(results_dict_filepath.exists())
        results_dict_smpl = pickle.load(results_dict_filepath.open('rb'))
        # print(results)
        cloth_state = results_dict_smpl["cloth_state"]

        # Load the garment information dictionary.
        accessor = Cloth3DCanonicalAccessor(CLOTH3D_PATH)
        sample_data = accessor.get_sample_data(sample_id, garment_name)

        # Load the blend file.
        bpy.ops.wm.open_mainfile(filepath=full_animation_blend_path.as_posix())

        info = get_info(CLOTH3D_PATH, sample_id)
        garment_texture = get_garment_texture(CLOTH3D_PATH, sample_id, garment_name, info=info)
        garment_meta = get_garment_metadata(CLOTH3D_PATH, sample_id, garment_name, info=info)
        gender = garment_meta['gender']
        fabric = garment_meta['garment_fabric']

        enable_gpu_renders()
        render_dylan(
            output_path=sample_dir, 
            sample_id=sample_id, 
            garment_name=garment_name, 
            gender=gender, 
            fabric=fabric, 
            garment_verts=cloth_state["verts"], 
            garment_faces=cloth_state["faces"],
            garment_uv_verts=cloth_state["uv_verts"], 
            garment_uv_faces=cloth_state["uv_faces"], 
            garment_texture=garment_texture, 
            num_camera_angles=1, 
            camera_intrinsic=camera_intrinsic,
            render_animation=True,
            z_offset=-0.4
        )
# Out:
# Animating 00471_Tshirt_153, action sequence: 0
# Animating 07135_Tshirt_4909, action sequence: 0
# Animating 07516_Tshirt_2950, action sequence: 0
# Animating 04199_Tshirt_3855, action sequence: 0
# Animating 04956_Tshirt_2092, action sequence: 0
# Animating 06698_Tshirt_321, action sequence: 0
# Animating 01841_Tshirt_2878, action sequence: 0
# Animating 05440_Tshirt_1903, action sequence: 0
# Animating 03685_Tshirt_3008, action sequence: 0
# Animating 06305_Tshirt_44, action sequence: 0
# Animating 05739_Tshirt_174, action sequence: 0
# Animating 04571_Tshirt_4765, action sequence: 0
# Animating 04325_Tshirt_3309, action sequence: 0
# Animating 05839_Tshirt_3309, action sequence: 0
# Animating 00387_Tshirt_2659, action sequence: 0
# Animating 03965_Tshirt_3646, action sequence: 0
# Animating 07516_Tshirt_3262, action sequence: 0
# Animating 04891_Tshirt_4354, action sequence: 0
# Animating 05542_Tshirt_3908, action sequence: 0
# Animating 06105_Tshirt_80, action sequence: 0
# Animating 05739_Tshirt_3482, action sequence: 0
# Animating 03966_Tshirt_34, action sequence: 0
# Animating 06165_Tshirt_2709, action sequence: 0
# Animating 02952_Tshirt_3909, action sequence: 0
# Animating 00380_Tshirt_509, action sequence: 0
# Animating 00471_Tshirt_153, action sequence: 1
# Animating 07135_Tshirt_4909, action sequence: 1
# Animating 07516_Tshirt_2950, action sequence: 1
# Animating 04199_Tshirt_3855, action sequence: 1
# Animating 04956_Tshirt_2092, action sequence: 1
# Animating 06698_Tshirt_321, action sequence: 1
# Animating 01841_Tshirt_2878, action sequence: 1
# Animating 05440_Tshirt_1903, action sequence: 1
# Animating 03685_Tshirt_3008, action sequence: 1
# Animating 06305_Tshirt_44, action sequence: 1
# Animating 05739_Tshirt_174, action sequence: 1
# Animating 04571_Tshirt_4765, action sequence: 1
# Animating 04325_Tshirt_3309, action sequence: 1
# Animating 05839_Tshirt_3309, action sequence: 1
# Animating 00387_Tshirt_2659, action sequence: 1
# Animating 03965_Tshirt_3646, action sequence: 1
# Animating 07516_Tshirt_3262, action sequence: 1
# Animating 04891_Tshirt_4354, action sequence: 1
# Animating 05542_Tshirt_3908, action sequence: 1
# Animating 06105_Tshirt_80, action sequence: 1
# Animating 05739_Tshirt_3482, action sequence: 1
# Animating 03966_Tshirt_34, action sequence: 1
# Animating 06165_Tshirt_2709, action sequence: 1
# Animating 02952_Tshirt_3909, action sequence: 1
# Animating 00380_Tshirt_509, action sequence: 1
# Animating 00471_Tshirt_153, action sequence: 2
# Animating 07135_Tshirt_4909, action sequence: 2
# Animating 07516_Tshirt_2950, action sequence: 2
# Animating 04199_Tshirt_3855, action sequence: 2
# Animating 04956_Tshirt_2092, action sequence: 2
# Animating 06698_Tshirt_321, action sequence: 2
# Animating 01841_Tshirt_2878, action sequence: 2
# Animating 05440_Tshirt_1903, action sequence: 2
# Animating 03685_Tshirt_3008, action sequence: 2
# Animating 06305_Tshirt_44, action sequence: 2
# Animating 05739_Tshirt_174, action sequence: 2
# Animating 04571_Tshirt_4765, action sequence: 2
# Animating 04325_Tshirt_3309, action sequence: 2
# Animating 05839_Tshirt_3309, action sequence: 2
# Animating 00387_Tshirt_2659, action sequence: 2
# Animating 03965_Tshirt_3646, action sequence: 2
# Animating 07516_Tshirt_3262, action sequence: 2
# Animating 04891_Tshirt_4354, action sequence: 2
# Animating 05542_Tshirt_3908, action sequence: 2
# Animating 06105_Tshirt_80, action sequence: 2
# Animating 05739_Tshirt_3482, action sequence: 2
# Animating 03966_Tshirt_34, action sequence: 2
# Animating 06165_Tshirt_2709, action sequence: 2
# Animating 02952_Tshirt_3909, action sequence: 2
# Animating 00380_Tshirt_509, action sequence: 2
# Animating 00471_Tshirt_153, action sequence: 3
# Animating 07135_Tshirt_4909, action sequence: 3
# Animating 07516_Tshirt_2950, action sequence: 3
# Animating 04199_Tshirt_3855, action sequence: 3
# Animating 04956_Tshirt_2092, action sequence: 3
# Animating 06698_Tshirt_321, action sequence: 3
# Animating 01841_Tshirt_2878, action sequence: 3
# Animating 05440_Tshirt_1903, action sequence: 3
# Animating 03685_Tshirt_3008, action sequence: 3
# Animating 06305_Tshirt_44, action sequence: 3
# Animating 05739_Tshirt_174, action sequence: 3
# Animating 04571_Tshirt_4765, action sequence: 3
# Animating 04325_Tshirt_3309, action sequence: 3
# Animating 05839_Tshirt_3309, action sequence: 3
# Animating 00387_Tshirt_2659, action sequence: 3
# Animating 03965_Tshirt_3646, action sequence: 3
# Animating 07516_Tshirt_3262, action sequence: 3
# Animating 04891_Tshirt_4354, action sequence: 3
# Animating 05542_Tshirt_3908, action sequence: 3
# Animating 06105_Tshirt_80, action sequence: 3
# Animating 05739_Tshirt_3482, action sequence: 3
# Animating 03966_Tshirt_34, action sequence: 3
# Animating 06165_Tshirt_2709, action sequence: 3
# Animating 02952_Tshirt_3909, action sequence: 3
# Animating 00380_Tshirt_509, action sequence: 3
# Animating 00471_Tshirt_153, action sequence: 4
# Animating 07135_Tshirt_4909, action sequence: 4
# Animating 07516_Tshirt_2950, action sequence: 4
# Animating 04199_Tshirt_3855, action sequence: 4
# Animating 04956_Tshirt_2092, action sequence: 4
# Animating 06698_Tshirt_321, action sequence: 4
# Animating 01841_Tshirt_2878, action sequence: 4
# Animating 05440_Tshirt_1903, action sequence: 4
# Animating 03685_Tshirt_3008, action sequence: 4
# Animating 06305_Tshirt_44, action sequence: 4
# Animating 05739_Tshirt_174, action sequence: 4
# Animating 04571_Tshirt_4765, action sequence: 4
# Animating 04325_Tshirt_3309, action sequence: 4
# Animating 05839_Tshirt_3309, action sequence: 4
# Animating 00387_Tshirt_2659, action sequence: 4
# Animating 03965_Tshirt_3646, action sequence: 4
# Animating 07516_Tshirt_3262, action sequence: 4
# Animating 04891_Tshirt_4354, action sequence: 4
# Animating 05542_Tshirt_3908, action sequence: 4
# Animating 06105_Tshirt_80, action sequence: 4
# Animating 05739_Tshirt_3482, action sequence: 4
# Animating 03966_Tshirt_34, action sequence: 4
# Animating 06165_Tshirt_2709, action sequence: 4
# Animating 02952_Tshirt_3909, action sequence: 4
# Animating 00380_Tshirt_509, action sequence: 4
# Animating 00471_Tshirt_153, action sequence: 5
# Animating 07135_Tshirt_4909, action sequence: 5
# Animating 07516_Tshirt_2950, action sequence: 5
# Animating 04199_Tshirt_3855, action sequence: 5
# Animating 04956_Tshirt_2092, action sequence: 5
# Animating 06698_Tshirt_321, action sequence: 5
# Animating 01841_Tshirt_2878, action sequence: 5
# Animating 05440_Tshirt_1903, action sequence: 5
# Animating 03685_Tshirt_3008, action sequence: 5
# Animating 06305_Tshirt_44, action sequence: 5
# Animating 05739_Tshirt_174, action sequence: 5
# Animating 04571_Tshirt_4765, action sequence: 5
# Animating 04325_Tshirt_3309, action sequence: 5
# Animating 05839_Tshirt_3309, action sequence: 5
# Animating 00387_Tshirt_2659, action sequence: 5
# Animating 03965_Tshirt_3646, action sequence: 5
# Animating 07516_Tshirt_3262, action sequence: 5
# Animating 04891_Tshirt_4354, action sequence: 5
# Animating 05542_Tshirt_3908, action sequence: 5
# Animating 06105_Tshirt_80, action sequence: 5
# Animating 05739_Tshirt_3482, action sequence: 5
# Animating 03966_Tshirt_34, action sequence: 5
# Animating 06165_Tshirt_2709, action sequence: 5
# Animating 02952_Tshirt_3909, action sequence: 5
# Animating 00380_Tshirt_509, action sequence: 5
# Animating 00471_Tshirt_153, action sequence: 6
# Animating 07135_Tshirt_4909, action sequence: 6
# Animating 07516_Tshirt_2950, action sequence: 6
# Animating 04199_Tshirt_3855, action sequence: 6
# Animating 04956_Tshirt_2092, action sequence: 6
# Animating 06698_Tshirt_321, action sequence: 6
# Animating 01841_Tshirt_2878, action sequence: 6
# Animating 05440_Tshirt_1903, action sequence: 6
# Animating 03685_Tshirt_3008, action sequence: 6
# Animating 06305_Tshirt_44, action sequence: 6
# Animating 05739_Tshirt_174, action sequence: 6
# Animating 04571_Tshirt_4765, action sequence: 6
# Animating 04325_Tshirt_3309, action sequence: 6
# Animating 05839_Tshirt_3309, action sequence: 6
# Animating 00387_Tshirt_2659, action sequence: 6
# Animating 03965_Tshirt_3646, action sequence: 6
# Animating 07516_Tshirt_3262, action sequence: 6
# Animating 04891_Tshirt_4354, action sequence: 6
# Animating 05542_Tshirt_3908, action sequence: 6
# Animating 06105_Tshirt_80, action sequence: 6
# Animating 05739_Tshirt_3482, action sequence: 6
# Animating 03966_Tshirt_34, action sequence: 6
# Animating 06165_Tshirt_2709, action sequence: 6
# Animating 02952_Tshirt_3909, action sequence: 6
# Animating 00380_Tshirt_509, action sequence: 6
# Animating 00471_Tshirt_153, action sequence: 7
# Animating 07135_Tshirt_4909, action sequence: 7
# Animating 07516_Tshirt_2950, action sequence: 7
# Animating 04199_Tshirt_3855, action sequence: 7
# Animating 04956_Tshirt_2092, action sequence: 7
# Animating 06698_Tshirt_321, action sequence: 7
# Animating 01841_Tshirt_2878, action sequence: 7
# Animating 05440_Tshirt_1903, action sequence: 7
# Animating 03685_Tshirt_3008, action sequence: 7
# Animating 06305_Tshirt_44, action sequence: 7
# Animating 05739_Tshirt_174, action sequence: 7
# Animating 04571_Tshirt_4765, action sequence: 7
# Animating 04325_Tshirt_3309, action sequence: 7
# Animating 05839_Tshirt_3309, action sequence: 7
# Animating 00387_Tshirt_2659, action sequence: 7
# Animating 03965_Tshirt_3646, action sequence: 7
# Animating 07516_Tshirt_3262, action sequence: 7
# Animating 04891_Tshirt_4354, action sequence: 7
# Animating 05542_Tshirt_3908, action sequence: 7
# Animating 06105_Tshirt_80, action sequence: 7
# Animating 05739_Tshirt_3482, action sequence: 7
# Animating 03966_Tshirt_34, action sequence: 7
# Animating 06165_Tshirt_2709, action sequence: 7
# Animating 02952_Tshirt_3909, action sequence: 7
# Animating 00380_Tshirt_509, action sequence: 7
# Animating 00471_Tshirt_153, action sequence: 8
# Animating 07135_Tshirt_4909, action sequence: 8
# Animating 07516_Tshirt_2950, action sequence: 8
# Animating 04199_Tshirt_3855, action sequence: 8
# Animating 04956_Tshirt_2092, action sequence: 8
# Animating 06698_Tshirt_321, action sequence: 8
# Animating 01841_Tshirt_2878, action sequence: 8
# Animating 05440_Tshirt_1903, action sequence: 8
# Animating 03685_Tshirt_3008, action sequence: 8
# Animating 06305_Tshirt_44, action sequence: 8
# Animating 05739_Tshirt_174, action sequence: 8
# Animating 04571_Tshirt_4765, action sequence: 8
# Animating 04325_Tshirt_3309, action sequence: 8
# Animating 05839_Tshirt_3309, action sequence: 8
# Animating 00387_Tshirt_2659, action sequence: 8
# Animating 03965_Tshirt_3646, action sequence: 8
# Animating 07516_Tshirt_3262, action sequence: 8
# Animating 04891_Tshirt_4354, action sequence: 8
# Animating 05542_Tshirt_3908, action sequence: 8
# Animating 06105_Tshirt_80, action sequence: 8
# Animating 05739_Tshirt_3482, action sequence: 8
# Animating 03966_Tshirt_34, action sequence: 8
# Animating 06165_Tshirt_2709, action sequence: 8
# Animating 02952_Tshirt_3909, action sequence: 8
# Animating 00380_Tshirt_509, action sequence: 8
# Animating 00471_Tshirt_153, action sequence: 9
# Animating 07135_Tshirt_4909, action sequence: 9
# Animating 07516_Tshirt_2950, action sequence: 9
# Animating 04199_Tshirt_3855, action sequence: 9
# Animating 04956_Tshirt_2092, action sequence: 9
# Animating 06698_Tshirt_321, action sequence: 9
# Animating 01841_Tshirt_2878, action sequence: 9
# Animating 05440_Tshirt_1903, action sequence: 9
# Animating 03685_Tshirt_3008, action sequence: 9
# Animating 06305_Tshirt_44, action sequence: 9
# Animating 05739_Tshirt_174, action sequence: 9
# Animating 04571_Tshirt_4765, action sequence: 9
# Animating 04325_Tshirt_3309, action sequence: 9
# Animating 05839_Tshirt_3309, action sequence: 9
# Animating 00387_Tshirt_2659, action sequence: 9
# Animating 03965_Tshirt_3646, action sequence: 9
# Animating 07516_Tshirt_3262, action sequence: 9
# Animating 04891_Tshirt_4354, action sequence: 9
# Animating 05542_Tshirt_3908, action sequence: 9
# Animating 06105_Tshirt_80, action sequence: 9
# Animating 05739_Tshirt_3482, action sequence: 9
# Animating 03966_Tshirt_34, action sequence: 9
# Animating 06165_Tshirt_2709, action sequence: 9
# Animating 02952_Tshirt_3909, action sequence: 9
# Animating 00380_Tshirt_509, action sequence: 9
# Animating 00471_Tshirt_153, action sequence: 10
# Animating 07135_Tshirt_4909, action sequence: 10
# Animating 07516_Tshirt_2950, action sequence: 10
# Animating 04199_Tshirt_3855, action sequence: 10
# Animating 04956_Tshirt_2092, action sequence: 10
# Animating 06698_Tshirt_321, action sequence: 10
# Animating 01841_Tshirt_2878, action sequence: 10
# Animating 05440_Tshirt_1903, action sequence: 10
# Animating 03685_Tshirt_3008, action sequence: 10
# Animating 06305_Tshirt_44, action sequence: 10
# Animating 05739_Tshirt_174, action sequence: 10
# Animating 04571_Tshirt_4765, action sequence: 10
# Animating 04325_Tshirt_3309, action sequence: 10
# Animating 05839_Tshirt_3309, action sequence: 10
# Animating 00387_Tshirt_2659, action sequence: 10
# Animating 03965_Tshirt_3646, action sequence: 10
# Animating 07516_Tshirt_3262, action sequence: 10
# Animating 04891_Tshirt_4354, action sequence: 10
# Animating 05542_Tshirt_3908, action sequence: 10
# Animating 06105_Tshirt_80, action sequence: 10
# Animating 05739_Tshirt_3482, action sequence: 10
# Animating 03966_Tshirt_34, action sequence: 10
# Animating 06165_Tshirt_2709, action sequence: 10
# Animating 02952_Tshirt_3909, action sequence: 10
# Animating 00380_Tshirt_509, action sequence: 10
# Animating 00471_Tshirt_153, action sequence: 11
# Animating 07135_Tshirt_4909, action sequence: 11
# Animating 07516_Tshirt_2950, action sequence: 11
# Animating 04199_Tshirt_3855, action sequence: 11
# Animating 04956_Tshirt_2092, action sequence: 11
# Animating 06698_Tshirt_321, action sequence: 11
# Animating 01841_Tshirt_2878, action sequence: 11
# Animating 05440_Tshirt_1903, action sequence: 11
# Animating 03685_Tshirt_3008, action sequence: 11
# Animating 06305_Tshirt_44, action sequence: 11
# Animating 05739_Tshirt_174, action sequence: 11
# Animating 04571_Tshirt_4765, action sequence: 11
# Animating 04325_Tshirt_3309, action sequence: 11
# Animating 05839_Tshirt_3309, action sequence: 11
# Animating 00387_Tshirt_2659, action sequence: 11
# Animating 03965_Tshirt_3646, action sequence: 11
# Animating 07516_Tshirt_3262, action sequence: 11
# Animating 04891_Tshirt_4354, action sequence: 11
# Animating 05542_Tshirt_3908, action sequence: 11
# Animating 06105_Tshirt_80, action sequence: 11
# Animating 05739_Tshirt_3482, action sequence: 11
# Animating 03966_Tshirt_34, action sequence: 11
# Animating 06165_Tshirt_2709, action sequence: 11
# Animating 02952_Tshirt_3909, action sequence: 11
# Animating 00380_Tshirt_509, action sequence: 11
# Animating 00471_Tshirt_153, action sequence: 12
# Animating 07135_Tshirt_4909, action sequence: 12
# Animating 07516_Tshirt_2950, action sequence: 12
# Animating 04199_Tshirt_3855, action sequence: 12
# Animating 04956_Tshirt_2092, action sequence: 12
# Animating 06698_Tshirt_321, action sequence: 12
# Animating 01841_Tshirt_2878, action sequence: 12
# Animating 05440_Tshirt_1903, action sequence: 12
# Animating 03685_Tshirt_3008, action sequence: 12
# Animating 06305_Tshirt_44, action sequence: 12
# Animating 05739_Tshirt_174, action sequence: 12
# Animating 04571_Tshirt_4765, action sequence: 12
# Animating 04325_Tshirt_3309, action sequence: 12
# Animating 05839_Tshirt_3309, action sequence: 12
# Animating 00387_Tshirt_2659, action sequence: 12
# Animating 03965_Tshirt_3646, action sequence: 12
# Animating 07516_Tshirt_3262, action sequence: 12
# Animating 04891_Tshirt_4354, action sequence: 12
# Animating 05542_Tshirt_3908, action sequence: 12
# Animating 06105_Tshirt_80, action sequence: 12
# Animating 05739_Tshirt_3482, action sequence: 12
# Animating 03966_Tshirt_34, action sequence: 12
# Animating 06165_Tshirt_2709, action sequence: 12
# Animating 02952_Tshirt_3909, action sequence: 12
# Animating 00380_Tshirt_509, action sequence: 12
# Animating 00471_Tshirt_153, action sequence: 13
# Animating 07135_Tshirt_4909, action sequence: 13
# Animating 07516_Tshirt_2950, action sequence: 13
# Animating 04199_Tshirt_3855, action sequence: 13
# Animating 04956_Tshirt_2092, action sequence: 13
# Animating 06698_Tshirt_321, action sequence: 13
# Animating 01841_Tshirt_2878, action sequence: 13
# Animating 05440_Tshirt_1903, action sequence: 13
# Animating 03685_Tshirt_3008, action sequence: 13
# Animating 06305_Tshirt_44, action sequence: 13
# Animating 05739_Tshirt_174, action sequence: 13
# Animating 04571_Tshirt_4765, action sequence: 13
# Animating 04325_Tshirt_3309, action sequence: 13
# Animating 05839_Tshirt_3309, action sequence: 13
# Animating 00387_Tshirt_2659, action sequence: 13
# Animating 03965_Tshirt_3646, action sequence: 13
# Animating 07516_Tshirt_3262, action sequence: 13
# Animating 04891_Tshirt_4354, action sequence: 13
# Animating 05542_Tshirt_3908, action sequence: 13
# Animating 06105_Tshirt_80, action sequence: 13
# Animating 05739_Tshirt_3482, action sequence: 13
# Animating 03966_Tshirt_34, action sequence: 13
# Animating 06165_Tshirt_2709, action sequence: 13
# Animating 02952_Tshirt_3909, action sequence: 13
# Animating 00380_Tshirt_509, action sequence: 13
# Animating 00471_Tshirt_153, action sequence: 14
# Animating 07135_Tshirt_4909, action sequence: 14
# Animating 07516_Tshirt_2950, action sequence: 14
# Animating 04199_Tshirt_3855, action sequence: 14
# Animating 04956_Tshirt_2092, action sequence: 14
# Animating 06698_Tshirt_321, action sequence: 14
# Animating 01841_Tshirt_2878, action sequence: 14
# Animating 05440_Tshirt_1903, action sequence: 14
# Animating 03685_Tshirt_3008, action sequence: 14
# Animating 06305_Tshirt_44, action sequence: 14
# Animating 05739_Tshirt_174, action sequence: 14
# Animating 04571_Tshirt_4765, action sequence: 14
# Animating 04325_Tshirt_3309, action sequence: 14
# Animating 05839_Tshirt_3309, action sequence: 14
# Animating 00387_Tshirt_2659, action sequence: 14
# Animating 03965_Tshirt_3646, action sequence: 14
# Animating 07516_Tshirt_3262, action sequence: 14
# Animating 04891_Tshirt_4354, action sequence: 14
# Animating 05542_Tshirt_3908, action sequence: 14
# Animating 06105_Tshirt_80, action sequence: 14
# Animating 05739_Tshirt_3482, action sequence: 14
# Animating 03966_Tshirt_34, action sequence: 14
# Animating 06165_Tshirt_2709, action sequence: 14
# Animating 02952_Tshirt_3909, action sequence: 14
# Animating 00380_Tshirt_509, action sequence: 14
